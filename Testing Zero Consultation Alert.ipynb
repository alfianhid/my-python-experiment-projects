# %%
import pandas as pd

# %%
data = {
    'table_name': ['bookings', 'orders', 'payments', 'consultations', 'lawyer_ratings', 'lawyer_configurations', 'clients', 'expired_bookings'],
    'row_count': [0, 0, 0, 0, 0, 59, 46, 2]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#               table_name  row_count
# 0               bookings          0
# 1                 orders          0
# 2               payments          0
# 3          consultations          0
# 4         lawyer_ratings          0
# 5  lawyer_configurations         59
# 6                clients         46
# 7       expired_bookings          2

# %%
# Exclude the 'lawyer_configurations' and 'clients' row from the DataFrame
filtered_df = df.loc[
            (df["table_name"] != "lawyer_configurations")
            & (df["table_name"] != "clients")
            & (df["table_name"] != "expired_bookings")
        ]
filtered_df
# Out:
#        table_name  row_count
# 0        bookings          0
# 1          orders          0
# 2        payments          0
# 3   consultations          0
# 4  lawyer_ratings          0

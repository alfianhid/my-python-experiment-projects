# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
import json
from google_play_scraper import app

result = app(
    'com.hukumku',
    lang='en', # defaults to 'en'
    country='us' # defaults to 'us'
)

# %%
print(json.dumps(result, sort_keys=True, indent=4))
# Out:
# {
#     "adSupported": false,
#     "appId": "com.hukumku",
#     "categories": [
#         {
#             "id": "BUSINESS",
#             "name": "Business"
#         }
#     ],
#     "comments": [],
#     "containsAds": false,
#     "contentRating": "Everyone 10+",
#     "contentRatingDescription": null,
#     "currency": "USD",
#     "description": "Hukumku - Trusted Legal Consultation Platform\r\n\r\nHukumku is an innovative app that connects you with hundreds of experienced legal\r\npractitioners ready to help you solve various legal issues. Through Hukumku, you can get\r\nreal-time legal consultations at an affordable cost with guaranteed data privacy protection.\r\n\r\nAdvantages of Hukumku:\r\nReal-Time Consultation: Get legal advice anytime and anywhere from our experienced\r\nadvocates. No need to wait long to get the legal solutions you need.\r\nAffordable Rates: Enjoy legal services at budget-friendly prices, starting from just $3.50.\r\nAccess professional legal assistance without breaking the bank.\r\nData Privacy Security: We understand the importance of your privacy. Hukumku ensures that\r\nall your personal data is safe and protected with the highest security standards.\r\nWide Range of Legal Areas: Hukumku covers various legal fields, from family law, civil law,\r\nand criminal law to business law. Whatever your legal issue, we have the right legal\r\npractitioners to assist you.\r\nWhy Choose Hukumku?\r\nEasy and Quick: Register and start your consultation in just a few easy steps. No need to\r\nspend hours searching for the right advocate.\r\nProfessional and Experienced: All our advocates have gone through a rigorous selection\r\nprocess and are officially licensed, ensuring you receive high-quality legal services.\r\nFlexibility: Schedule consultations according to your availability. Enjoy the flexibility of getting\r\nlegal help without disrupting your daily activities.\r\n\r\nDownload Hukumku now and experience the ease of getting legal assistance at your fingertips!",
#     "descriptionHTML": "Hukumku - Trusted Legal Consultation Platform<br><br>Hukumku is an innovative app that connects you with hundreds of experienced legal<br>practitioners ready to help you solve various legal issues. Through Hukumku, you can get<br>real-time legal consultations at an affordable cost with guaranteed data privacy protection.<br><br>Advantages of Hukumku:<br>Real-Time Consultation: Get legal advice anytime and anywhere from our experienced<br>advocates. No need to wait long to get the legal solutions you need.<br>Affordable Rates: Enjoy legal services at budget-friendly prices, starting from just $3.50.<br>Access professional legal assistance without breaking the bank.<br>Data Privacy Security: We understand the importance of your privacy. Hukumku ensures that<br>all your personal data is safe and protected with the highest security standards.<br>Wide Range of Legal Areas: Hukumku covers various legal fields, from family law, civil law,<br>and criminal law to business law. Whatever your legal issue, we have the right legal<br>practitioners to assist you.<br>Why Choose Hukumku?<br>Easy and Quick: Register and start your consultation in just a few easy steps. No need to<br>spend hours searching for the right advocate.<br>Professional and Experienced: All our advocates have gone through a rigorous selection<br>process and are officially licensed, ensuring you receive high-quality legal services.<br>Flexibility: Schedule consultations according to your availability. Enjoy the flexibility of getting<br>legal help without disrupting your daily activities.<br><br>Download Hukumku now and experience the ease of getting legal assistance at your fingertips!",
#     "developer": "PT Teknologi Legal Bersama",
#     "developerAddress": null,
#     "developerEmail": "admin@hukumku.id",
#     "developerId": "5698065753540738492",
#     "developerWebsite": "https://www.hukumku.id",
#     "free": true,
#     "genre": "Business",
#     "genreId": "BUSINESS",
#     "headerImage": "https://play-lh.googleusercontent.com/oHMDOV79-Q0J6H-Uk6tNFdCmpVkjnD9GTbSYXBLTy2Z3Jl91in2QTAXoZPiEqHYw0kI",
#     "histogram": [
#         0,
#         0,
#         0,
#         0,
#         0
#     ],
#     "icon": "https://play-lh.googleusercontent.com/UKZUi4HLTKs2iJgTfyvC5w33ImnmAiAfMwy9tT_IpmrrlJpsY-5vi32PLS5bUrLqVUw",
#     "inAppProductPrice": null,
#     "installs": "5,000+",
#     "lastUpdatedOn": "Jun 10, 2024",
#     "minInstalls": 5000,
#     "offersIAP": false,
#     "originalPrice": null,
#     "price": 0,
#     "privacyPolicy": "https://www.hukumku.id/kebijakan-privasi",
#     "ratings": null,
#     "realInstalls": 5002,
#     "released": "Dec 6, 2023",
#     "reviews": null,
#     "sale": false,
#     "saleText": null,
#     "saleTime": null,
#     "score": null,
#     "screenshots": [
#         "https://play-lh.googleusercontent.com/NhAg3GQoPc_mtViCt-emi5pqgA13i23HLFfFnC_ELiKmvnFzyYfq4QF8pCZCO-4vpw",
#         "https://play-lh.googleusercontent.com/lXOtMDOVqu_4PvbgU3EfNQ2IKl-nyGQu9n7Dv0cuJeZEmT6A_jAyUil-Y9M34p2uROFj",
#         "https://play-lh.googleusercontent.com/JqWuzYkQzBO9-hKOK0n0kk-FY1T8qHAvp5WMFw8zWYlHVCcq6pxyqaaZh4hptJNK28w",
#         "https://play-lh.googleusercontent.com/diCtUWoNMSyrgaZiqAwqn1CEjDQrJheYAaTVID4wcd6L2r-0TZWaUJUh_fWbrXLIuw",
#         "https://play-lh.googleusercontent.com/RGESOTNvtDgEMvFgnJUopYYlsZ733wwnPOmccZA_aMPZ-iErbg99kg4mEh_ym4AuYc0",
#         "https://play-lh.googleusercontent.com/aDniy-cIVdZBozKlQe7jYOs7a0AOlQYiYm2ROvBJwf5VKthJj81XC2HBYpfJyHlJZ4LM",
#         "https://play-lh.googleusercontent.com/4ctqS1jqKrdslNhoLCBWys-XLRROV_44TXSY9QrCwMH65i8kuleOEIsJGk_K88wuq4c",
#         "https://play-lh.googleusercontent.com/3Nz61BmWIALjRnqwJ4WJfmSzDl8LObH6N6W7v4nbr5EJkNqdXWKzemZ8WzxcG7LI5sc",
#         "https://play-lh.googleusercontent.com/MzRClygdt69qzkiv-p1xoifcJyH_10VDk4NMqAGd-Utzrwsqa70oxuM3a3qwB9kfjjE",
#         "https://play-lh.googleusercontent.com/O_ftks6mYyJyfnc8mtLx2e3OagMYgqRHmwwadCwRPJvbjBaVfD2jT4EfPgIpp6jpWDYx",
#         "https://play-lh.googleusercontent.com/9IgVhticNqsKKJBicGFHgAusY63Nt4V3ym5CSHpD2twCplnwxJ1EOZ0GngM7utK2wRY",
#         "https://play-lh.googleusercontent.com/Z0BvNNNDstAVcOtoIBDYx0hdiG1z0RziDzCQOj15SpWUp7TUBeHkmHWLEtjyi6ARavS4",
#         "https://play-lh.googleusercontent.com/CX2LomHpdEbiQSYO_AkqmEPRfA0ezCB1vzdTqaWtB2h8uRwaF9ZoAkS5TJ9ULcFm4nc",
#         "https://play-lh.googleusercontent.com/0-M-mveDeVX95CYlxBHz0sgsf-FlO81Z12isERo1WdO3a9zTw1woAhjpFemcK5WEcg",
#         "https://play-lh.googleusercontent.com/j-y86_xEJI5dnwNCg7qbuQRBqh_OqY7rX3PBJqiFU1irBvkijWvZ-rSlu2LSy0-zMBs",
#         "https://play-lh.googleusercontent.com/c2rpYCG1XGy4cICEceGlP9A0NGvsP9A-zsEg7aCKikkyu_v2ZAxfIaxQSBMKYmi_Vg"
#     ],
#     "summary": "Digital platform to resolve Indonesian society's legal problems",
#     "title": "Hukumku",
#     "updated": 1718075670,
#     "url": "https://play.google.com/store/apps/details?id=com.hukumku&hl=en&gl=us",
#     "version": "0.5.5",
#     "video": null,
#     "videoImage": null
# }

# %%
# !pip3 install python-app-store-scraper
# Out:
# Collecting python-app-store-scraper
#   Downloading python_app_store_scraper-1.1.1-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from python-app-store-scraper) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->python-app-store-scraper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->python-app-store-scraper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->python-app-store-scraper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->python-app-store-scraper) (2024.6.2)
# Installing collected packages: python-app-store-scraper
# Successfully installed python-app-store-scraper-1.1.1

# %%
from app_store_scraper import AppStore
from pprint import pprint

hukumku = AppStore(country="id", app_name="hukumku")
pprint(hukumku)
# Out:
# AppStore(country='id', app_name='hukumku', app_id=6474131392)
